# %%
# !pip install -U langchain-community
# !pip install -U langchain-huggingface
# !pip install -U sentence-transformers
# !pip install -U langchain-chroma
# !pip install -U faiss-cpu
# !pip install wikipedia
# Out:
# Requirement already satisfied: langchain-community in e:\langchain_models\venv\lib\site-packages (0.4.2)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in e:\langchain_models\venv\lib\site-packages (from langchain-community) (2.14.2)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in e:\langchain_models\venv\lib\site-packages (from langchain-community) (2.0.51)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in e:\langchain_models\venv\lib\site-packages (from langchain-community) (0.8.16)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in e:\langchain_models\venv\lib\site-packages (from langchain-community) (3.14.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in e:\langchain_models\venv\lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.0 in e:\langchain_models\venv\lib\site-packages (from langchain-community) (1.4.9)
# Requirement already satisfied: numpy>=1.26.2 in e:\langchain_models\venv\lib\site-packages (from langchain-community) (2.2.6)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in e:\langchain_models\venv\lib\site-packages (from langchain-community) (6.0.3)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.7 in e:\langchain_models\venv\lib\site-packages (from langchain-community) (1.0.8)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in e:\langchain_models\venv\lib\site-packages (from langchain-community) (2.34.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in e:\langchain_models\venv\lib\site-packages (from langchain-community) (9.1.4)
# Requirement already satisfied: frozenlist>=1.1.1 in e:\langchain_models\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: aiosignal>=1.4.0 in e:\langchain_models\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in e:\langchain_models\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.7.1)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in e:\langchain_models\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (4.0.3)
# Requirement already satisfied: propcache>=0.2.0 in e:\langchain_models\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in e:\langchain_models\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.24.2)
# Requirement already satisfied: attrs>=17.3.0 in e:\langchain_models\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (26.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in e:\langchain_models\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: typing_extensions>=4.4 in e:\langchain_models\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (4.15.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in e:\langchain_models\venv\lib\site-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community) (1.1.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in e:\langchain_models\venv\lib\site-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community) (2.13.4)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in e:\langchain_models\venv\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (0.16.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in e:\langchain_models\venv\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in e:\langchain_models\venv\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (0.0.17)
# Requirement already satisfied: packaging>=23.2.0 in e:\langchain_models\venv\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-community) (26.2)
# Requirement already satisfied: zstandard>=0.23.0 in e:\langchain_models\venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.25.0)
# Requirement already satisfied: websockets>=15.0 in e:\langchain_models\venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (15.0.1)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in e:\langchain_models\venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in e:\langchain_models\venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.7.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in e:\langchain_models\venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in e:\langchain_models\venv\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.11.9)
# Requirement already satisfied: python-dotenv>=0.21.0 in e:\langchain_models\venv\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in e:\langchain_models\venv\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (0.4.2)
# Requirement already satisfied: idna<4,>=2.5 in e:\langchain_models\venv\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.18)
# Requirement already satisfied: certifi>=2023.5.7 in e:\langchain_models\venv\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2026.5.20)
# Requirement already satisfied: charset_normalizer<4,>=2 in e:\langchain_models\venv\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in e:\langchain_models\venv\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.7.0)
# Requirement already satisfied: greenlet>=1 in e:\langchain_models\venv\lib\site-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-community) (3.5.3)
# Requirement already satisfied: httpcore==1.* in e:\langchain_models\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: anyio in e:\langchain_models\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (4.14.0)
# Requirement already satisfied: h11>=0.16 in e:\langchain_models\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in e:\langchain_models\venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.0->langchain-community) (3.1.1)
# Requirement already satisfied: annotated-types>=0.6.0 in e:\langchain_models\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in e:\langchain_models\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain-community) (2.46.4)
# Requirement already satisfied: exceptiongroup>=1.0.2 in e:\langchain_models\venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.3.1)
# [notice] A new release of pip is available: 23.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: langchain-huggingface in e:\langchain_models\venv\lib\site-packages (1.2.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.31 in e:\langchain_models\venv\lib\site-packages (from langchain-huggingface) (1.4.9)
# Requirement already satisfied: huggingface-hub<2.0.0,>=0.33.4 in e:\langchain_models\venv\lib\site-packages (from langchain-huggingface) (1.19.0)
# Requirement already satisfied: tokenizers<1.0.0,>=0.19.1 in e:\langchain_models\venv\lib\site-packages (from langchain-huggingface) (0.22.2)
# Requirement already satisfied: filelock>=3.10.0 in e:\langchain_models\venv\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (3.29.4)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in e:\langchain_models\venv\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (1.5.1)
# Requirement already satisfied: click>=8.4.0 in e:\langchain_models\venv\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (8.4.1)
# Requirement already satisfied: pyyaml>=5.1 in e:\langchain_models\venv\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (6.0.3)
# Requirement already satisfied: typer<0.26.0,>=0.20.0 in e:\langchain_models\venv\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (0.25.1)
# Requirement already satisfied: packaging>=20.9 in e:\langchain_models\venv\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (26.2)
# Requirement already satisfied: typing-extensions>=4.1.0 in e:\langchain_models\venv\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (4.15.0)
# Requirement already satisfied: fsspec>=2023.5.0 in e:\langchain_models\venv\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (2026.6.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in e:\langchain_models\venv\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (0.28.1)
# Requirement already satisfied: tqdm>=4.42.1 in e:\langchain_models\venv\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (4.68.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in e:\langchain_models\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (0.16.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in e:\langchain_models\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in e:\langchain_models\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (0.0.17)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in e:\langchain_models\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (9.1.4)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in e:\langchain_models\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (0.8.16)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in e:\langchain_models\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (2.13.4)
# Requirement already satisfied: colorama in e:\langchain_models\venv\lib\site-packages (from click>=8.4.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (0.4.6)
# Requirement already satisfied: idna in e:\langchain_models\venv\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (3.18)
# Requirement already satisfied: certifi in e:\langchain_models\venv\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in e:\langchain_models\venv\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (1.0.9)
# Requirement already satisfied: anyio in e:\langchain_models\venv\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (4.14.0)
# Requirement already satisfied: h11>=0.16 in e:\langchain_models\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in e:\langchain_models\venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (3.1.1)
# Requirement already satisfied: xxhash>=3.0.0 in e:\langchain_models\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (3.7.0)
# Requirement already satisfied: orjson>=3.9.14 in e:\langchain_models\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in e:\langchain_models\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (1.0.0)
# Requirement already satisfied: websockets>=15.0 in e:\langchain_models\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (15.0.1)
# Requirement already satisfied: requests>=2.0.0 in e:\langchain_models\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (2.34.2)
# Requirement already satisfied: zstandard>=0.23.0 in e:\langchain_models\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (0.25.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in e:\langchain_models\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (0.4.2)
# Requirement already satisfied: pydantic-core==2.46.4 in e:\langchain_models\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (2.46.4)
# Requirement already satisfied: annotated-types>=0.6.0 in e:\langchain_models\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (0.7.0)
# Requirement already satisfied: rich>=13.8.0 in e:\langchain_models\venv\lib\site-packages (from typer<0.26.0,>=0.20.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (15.0.0)
# Requirement already satisfied: shellingham>=1.3.0 in e:\langchain_models\venv\lib\site-packages (from typer<0.26.0,>=0.20.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in e:\langchain_models\venv\lib\site-packages (from typer<0.26.0,>=0.20.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (0.0.4)
# Requirement already satisfied: urllib3<3,>=1.26 in e:\langchain_models\venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (2.7.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in e:\langchain_models\venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-huggingface) (3.4.7)
# Requirement already satisfied: markdown-it-py>=2.2.0 in e:\langchain_models\venv\lib\site-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in e:\langchain_models\venv\lib\site-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (2.20.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in e:\langchain_models\venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (1.3.1)
# Requirement already satisfied: mdurl~=0.1 in e:\langchain_models\venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (0.1.2)
# [notice] A new release of pip is available: 23.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: sentence-transformers in e:\langchain_models\venv\lib\site-packages (5.6.0)
# Requirement already satisfied: tqdm>=4.0.0 in e:\langchain_models\venv\lib\site-packages (from sentence-transformers) (4.68.2)
# Requirement already satisfied: scikit-learn>=0.22.0 in e:\langchain_models\venv\lib\site-packages (from sentence-transformers) (1.7.2)
# Requirement already satisfied: huggingface-hub>=0.23.0 in e:\langchain_models\venv\lib\site-packages (from sentence-transformers) (1.19.0)
# Requirement already satisfied: scipy>=1.0.0 in e:\langchain_models\venv\lib\site-packages (from sentence-transformers) (1.15.3)
# Requirement already satisfied: typing_extensions>=4.5.0 in e:\langchain_models\venv\lib\site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in e:\langchain_models\venv\lib\site-packages (from sentence-transformers) (5.12.1)
# Requirement already satisfied: torch>=1.11.0 in e:\langchain_models\venv\lib\site-packages (from sentence-transformers) (2.12.1)
# Requirement already satisfied: numpy>=1.20.0 in e:\langchain_models\venv\lib\site-packages (from sentence-transformers) (2.2.6)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in e:\langchain_models\venv\lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (1.5.1)
# Requirement already satisfied: filelock>=3.10.0 in e:\langchain_models\venv\lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (3.29.4)
# Requirement already satisfied: httpx<1,>=0.23.0 in e:\langchain_models\venv\lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in e:\langchain_models\venv\lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (26.2)
# Requirement already satisfied: typer<0.26.0,>=0.20.0 in e:\langchain_models\venv\lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (0.25.1)
# Requirement already satisfied: pyyaml>=5.1 in e:\langchain_models\venv\lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (6.0.3)
# Requirement already satisfied: fsspec>=2023.5.0 in e:\langchain_models\venv\lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (2026.6.0)
# Requirement already satisfied: click>=8.4.0 in e:\langchain_models\venv\lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (8.4.1)
# Requirement already satisfied: joblib>=1.2.0 in e:\langchain_models\venv\lib\site-packages (from scikit-learn>=0.22.0->sentence-transformers) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in e:\langchain_models\venv\lib\site-packages (from scikit-learn>=0.22.0->sentence-transformers) (3.6.0)
# Requirement already satisfied: sympy>=1.13.3 in e:\langchain_models\venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: jinja2 in e:\langchain_models\venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: setuptools<82 in e:\langchain_models\venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (65.5.0)
# Requirement already satisfied: networkx>=2.5.1 in e:\langchain_models\venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: colorama in e:\langchain_models\venv\lib\site-packages (from tqdm>=4.0.0->sentence-transformers) (0.4.6)
# Requirement already satisfied: regex>=2025.10.22 in e:\langchain_models\venv\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2026.5.9)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in e:\langchain_models\venv\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in e:\langchain_models\venv\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.8.0)
# Requirement already satisfied: idna in e:\langchain_models\venv\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (3.18)
# Requirement already satisfied: anyio in e:\langchain_models\venv\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (4.14.0)
# Requirement already satisfied: httpcore==1.* in e:\langchain_models\venv\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (1.0.9)
# Requirement already satisfied: certifi in e:\langchain_models\venv\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (2026.5.20)
# Requirement already satisfied: h11>=0.16 in e:\langchain_models\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (0.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in e:\langchain_models\venv\lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: rich>=13.8.0 in e:\langchain_models\venv\lib\site-packages (from typer<0.26.0,>=0.20.0->huggingface-hub>=0.23.0->sentence-transformers) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in e:\langchain_models\venv\lib\site-packages (from typer<0.26.0,>=0.20.0->huggingface-hub>=0.23.0->sentence-transformers) (0.0.4)
# Requirement already satisfied: shellingham>=1.3.0 in e:\langchain_models\venv\lib\site-packages (from typer<0.26.0,>=0.20.0->huggingface-hub>=0.23.0->sentence-transformers) (1.5.4)
# Requirement already satisfied: MarkupSafe>=2.0 in e:\langchain_models\venv\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in e:\langchain_models\venv\lib\site-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub>=0.23.0->sentence-transformers) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in e:\langchain_models\venv\lib\site-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub>=0.23.0->sentence-transformers) (2.20.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in e:\langchain_models\venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (1.3.1)
# Requirement already satisfied: mdurl~=0.1 in e:\langchain_models\venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub>=0.23.0->sentence-transformers) (0.1.2)
# [notice] A new release of pip is available: 23.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: langchain-chroma in e:\langchain_models\venv\lib\site-packages (1.1.0)
# Requirement already satisfied: chromadb<2.0.0,>=1.3.5 in e:\langchain_models\venv\lib\site-packages (from langchain-chroma) (1.5.9)
# Requirement already satisfied: langchain-core<2.0.0,>=1.1.3 in e:\langchain_models\venv\lib\site-packages (from langchain-chroma) (1.4.9)
# Requirement already satisfied: numpy>=1.26.0 in e:\langchain_models\venv\lib\site-packages (from langchain-chroma) (2.2.6)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in e:\langchain_models\venv\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.44.0)
# Requirement already satisfied: overrides>=7.3.1 in e:\langchain_models\venv\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (7.7.0)
# Requirement already satisfied: pydantic-settings>=2.0 in e:\langchain_models\venv\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.14.2)
# Requirement already satisfied: tenacity>=8.2.3 in e:\langchain_models\venv\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (9.1.4)
# Requirement already satisfied: typer>=0.9.0 in e:\langchain_models\venv\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.25.1)
# Requirement already satisfied: importlib-resources in e:\langchain_models\venv\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (7.1.0)
# Requirement already satisfied: grpcio>=1.58.0 in e:\langchain_models\venv\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.81.1)
# Requirement already satisfied: pydantic>=2.0 in e:\langchain_models\venv\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.13.4)
# Requirement already satisfied: httpx>=0.27.0 in e:\langchain_models\venv\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.28.1)
# Requirement already satisfied: tqdm>=4.65.0 in e:\langchain_models\venv\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (4.68.2)
# Requirement already satisfied: kubernetes>=28.1.0 in e:\langchain_models\venv\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (36.0.3)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in e:\langchain_models\venv\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.44.0)
# Requirement already satisfied: rich>=10.11.0 in e:\langchain_models\venv\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (15.0.0)
# Requirement already satisfied: pypika>=0.48.9 in e:\langchain_models\venv\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.51.1)
# Requirement already satisfied: orjson>=3.9.12 in e:\langchain_models\venv\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (3.11.9)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in e:\langchain_models\venv\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.44.0)
# Requirement already satisfied: pybase64>=1.4.1 in e:\langchain_models\venv\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.4.3)
# Requirement already satisfied: bcrypt>=4.0.1 in e:\langchain_models\venv\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (5.0.0)
# Requirement already satisfied: build>=1.0.3 in e:\langchain_models\venv\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.5.0)
# Requirement already satisfied: mmh3>=4.0.1 in e:\langchain_models\venv\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (5.2.1)
# Requirement already satisfied: uvicorn[standard]>=0.18.3 in e:\langchain_models\venv\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.49.0)
# Requirement already satisfied: pyyaml>=6.0.0 in e:\langchain_models\venv\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (6.0.3)
# Requirement already satisfied: onnxruntime>=1.14.1 in e:\langchain_models\venv\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.23.2)
# Requirement already satisfied: tokenizers>=0.13.2 in e:\langchain_models\venv\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.22.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in e:\langchain_models\venv\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (4.15.0)
# Requirement already satisfied: jsonschema>=4.19.0 in e:\langchain_models\venv\lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (4.26.0)
# Requirement already satisfied: packaging>=23.2.0 in e:\langchain_models\venv\lib\site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-chroma) (26.2)
# Requirement already satisfied: langchain-protocol>=0.0.17 in e:\langchain_models\venv\lib\site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-chroma) (0.0.17)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in e:\langchain_models\venv\lib\site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-chroma) (0.8.16)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in e:\langchain_models\venv\lib\site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-chroma) (1.33)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in e:\langchain_models\venv\lib\site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-chroma) (0.16.1)
# Requirement already satisfied: pyproject_hooks in e:\langchain_models\venv\lib\site-packages (from build>=1.0.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.2.0)
# Requirement already satisfied: tomli>=1.1.0 in e:\langchain_models\venv\lib\site-packages (from build>=1.0.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.4.1)
# Requirement already satisfied: colorama in e:\langchain_models\venv\lib\site-packages (from build>=1.0.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.4.6)
# Requirement already satisfied: certifi in e:\langchain_models\venv\lib\site-packages (from httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in e:\langchain_models\venv\lib\site-packages (from httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.0.9)
# Requirement already satisfied: idna in e:\langchain_models\venv\lib\site-packages (from httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (3.18)
# Requirement already satisfied: anyio in e:\langchain_models\venv\lib\site-packages (from httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (4.14.0)
# Requirement already satisfied: h11>=0.16 in e:\langchain_models\venv\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in e:\langchain_models\venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (3.1.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in e:\langchain_models\venv\lib\site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in e:\langchain_models\venv\lib\site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.37.0)
# Requirement already satisfied: attrs>=22.2.0 in e:\langchain_models\venv\lib\site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (26.1.0)
# Requirement already satisfied: rpds-py>=0.25.0 in e:\langchain_models\venv\lib\site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.30.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.13.5 in e:\langchain_models\venv\lib\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (3.14.1)
# Requirement already satisfied: durationpy>=0.7 in e:\langchain_models\venv\lib\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.10)
# Requirement already satisfied: six>=1.9.0 in e:\langchain_models\venv\lib\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in e:\langchain_models\venv\lib\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.6.0,>=1.24.2 in e:\langchain_models\venv\lib\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.7.0)
# Requirement already satisfied: requests-oauthlib in e:\langchain_models\venv\lib\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.0.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in e:\langchain_models\venv\lib\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.9.0)
# Requirement already satisfied: requests in e:\langchain_models\venv\lib\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.34.2)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in e:\langchain_models\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in e:\langchain_models\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (3.7.0)
# Requirement already satisfied: zstandard>=0.23.0 in e:\langchain_models\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (0.25.0)
# Requirement already satisfied: websockets>=15.0 in e:\langchain_models\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (15.0.1)
# Requirement already satisfied: flatbuffers in e:\langchain_models\venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain-chroma) (25.12.19)
# Requirement already satisfied: coloredlogs in e:\langchain_models\venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain-chroma) (15.0.1)
# Requirement already satisfied: protobuf in e:\langchain_models\venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain-chroma) (5.29.6)
# Requirement already satisfied: sympy in e:\langchain_models\venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.14.0)
# Requirement already satisfied: opentelemetry-proto==1.44.0 in e:\langchain_models\venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.44.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.44.0 in e:\langchain_models\venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.44.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in e:\langchain_models\venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.75.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.65b0 in e:\langchain_models\venv\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.65b0)
# Requirement already satisfied: typing-inspection>=0.4.2 in e:\langchain_models\venv\lib\site-packages (from pydantic>=2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.4.2)
# Requirement already satisfied: pydantic-core==2.46.4 in e:\langchain_models\venv\lib\site-packages (from pydantic>=2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.46.4)
# Requirement already satisfied: annotated-types>=0.6.0 in e:\langchain_models\venv\lib\site-packages (from pydantic>=2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.7.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in e:\langchain_models\venv\lib\site-packages (from pydantic-settings>=2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in e:\langchain_models\venv\lib\site-packages (from rich>=10.11.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in e:\langchain_models\venv\lib\site-packages (from rich>=10.11.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.20.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in e:\langchain_models\venv\lib\site-packages (from tokenizers>=0.13.2->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.19.0)
# Requirement already satisfied: shellingham>=1.3.0 in e:\langchain_models\venv\lib\site-packages (from typer>=0.9.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in e:\langchain_models\venv\lib\site-packages (from typer>=0.9.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.0.4)
# Requirement already satisfied: click>=8.2.1 in e:\langchain_models\venv\lib\site-packages (from typer>=0.9.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (8.4.1)
# Requirement already satisfied: watchfiles>=0.20 in e:\langchain_models\venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.2.0)
# Requirement already satisfied: httptools>=0.8.0 in e:\langchain_models\venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.8.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in e:\langchain_models\venv\lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (4.0.3)
# Requirement already satisfied: frozenlist>=1.1.1 in e:\langchain_models\venv\lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.8.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in e:\langchain_models\venv\lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in e:\langchain_models\venv\lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in e:\langchain_models\venv\lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (6.7.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in e:\langchain_models\venv\lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.24.2)
# Requirement already satisfied: propcache>=0.2.0 in e:\langchain_models\venv\lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.5.2)
# Requirement already satisfied: fsspec>=2023.5.0 in e:\langchain_models\venv\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2026.6.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in e:\langchain_models\venv\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.5.1)
# Requirement already satisfied: filelock>=3.10.0 in e:\langchain_models\venv\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb<2.0.0,>=1.3.5->langchain-chroma) (3.29.4)
# Requirement already satisfied: mdurl~=0.1 in e:\langchain_models\venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.1.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in e:\langchain_models\venv\lib\site-packages (from requests->kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (3.4.7)
# Requirement already satisfied: exceptiongroup>=1.0.2 in e:\langchain_models\venv\lib\site-packages (from anyio->httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.3.1)
# Requirement already satisfied: humanfriendly>=9.1 in e:\langchain_models\venv\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain-chroma) (10.0)
# Requirement already satisfied: oauthlib>=3.0.0 in e:\langchain_models\venv\lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in e:\langchain_models\venv\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.3.0)
# Requirement already satisfied: pyreadline3 in e:\langchain_models\venv\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain-chroma) (3.5.6)
# [notice] A new release of pip is available: 23.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.14.3-cp310-cp310-win_amd64.whl (16.2 MB)
#      ---------------------------------------- 0.0/16.2 MB ? eta -:--:--
#      --------------------------------------- 0.0/16.2 MB 991.0 kB/s eta 0:00:17
#      ---------------------------------------- 0.1/16.2 MB 1.6 MB/s eta 0:00:11
#       --------------------------------------- 0.3/16.2 MB 2.6 MB/s eta 0:00:07
#      - -------------------------------------- 0.7/16.2 MB 3.8 MB/s eta 0:00:05
#      -- ------------------------------------- 1.2/16.2 MB 5.3 MB/s eta 0:00:03
#      --- ------------------------------------ 1.6/16.2 MB 5.9 MB/s eta 0:00:03
#      ----- ---------------------------------- 2.2/16.2 MB 6.9 MB/s eta 0:00:03
#      ------ --------------------------------- 2.8/16.2 MB 7.6 MB/s eta 0:00:02
#      ------- -------------------------------- 2.9/16.2 MB 7.7 MB/s eta 0:00:02
#      ------- -------------------------------- 2.9/16.2 MB 7.7 MB/s eta 0:00:02
#      ------- -------------------------------- 3.0/16.2 MB 6.4 MB/s eta 0:00:03
#      -------- ------------------------------- 3.3/16.2 MB 5.9 MB/s eta 0:00:03
#      -------- ------------------------------- 3.4/16.2 MB 6.0 MB/s eta 0:00:03
#      -------- ------------------------------- 3.5/16.2 MB 5.4 MB/s eta 0:00:03
#      -------- ------------------------------- 3.5/16.2 MB 5.4 MB/s eta 0:00:03
#      -------- ------------------------------- 3.6/16.2 MB 4.9 MB/s eta 0:00:03
#      ---------- ----------------------------- 4.1/16.2 MB 5.2 MB/s eta 0:00:03
#      ---------- ----------------------------- 4.1/16.2 MB 5.3 MB/s eta 0:00:03
#      ---------- ----------------------------- 4.3/16.2 MB 4.9 MB/s eta 0:00:03
#      ----------- ---------------------------- 4.8/16.2 MB 5.2 MB/s eta 0:00:03
#      ------------- -------------------------- 5.3/16.2 MB 5.5 MB/s eta 0:00:02
#      ------------- -------------------------- 5.5/16.2 MB 5.6 MB/s eta 0:00:02
#      -------------- ------------------------- 5.8/16.2 MB 5.5 MB/s eta 0:00:02
#      --------------- ------------------------ 6.4/16.2 MB 5.8 MB/s eta 0:00:02
#      ---------------- ----------------------- 6.5/16.2 MB 5.8 MB/s eta 0:00:02
#      ----------------- ---------------------- 6.9/16.2 MB 5.8 MB/s eta 0:00:02
#      ------------------ --------------------- 7.5/16.2 MB 6.0 MB/s eta 0:00:02
#      -------------------- ------------------- 8.1/16.2 MB 6.3 MB/s eta 0:00:02
#      -------------------- ------------------- 8.5/16.2 MB 6.4 MB/s eta 0:00:02
#      --------------------- ------------------ 8.7/16.2 MB 6.3 MB/s eta 0:00:02
#      --------------------- ------------------ 8.7/16.2 MB 6.3 MB/s eta 0:00:02
#      --------------------- ------------------ 8.8/16.2 MB 5.9 MB/s eta 0:00:02
#      --------------------- ------------------ 8.8/16.2 MB 5.9 MB/s eta 0:00:02
#      ---------------------- ----------------- 9.0/16.2 MB 5.7 MB/s eta 0:00:02
#      ----------------------- ---------------- 9.5/16.2 MB 5.9 MB/s eta 0:00:02
#      ----------------------- ---------------- 9.5/16.2 MB 5.9 MB/s eta 0:00:02
#      ----------------------- ---------------- 9.6/16.2 MB 5.7 MB/s eta 0:00:02
#      ----------------------- ---------------- 9.6/16.2 MB 5.7 MB/s eta 0:00:02
#      ------------------------ --------------- 9.9/16.2 MB 5.5 MB/s eta 0:00:02
#      ------------------------ --------------- 10.0/16.2 MB 5.3 MB/s eta 0:00:02
#      ------------------------- -------------- 10.3/16.2 MB 5.5 MB/s eta 0:00:02
#      --------------------------- ------------ 10.9/16.2 MB 5.8 MB/s eta 0:00:01
#      ---------------------------- ----------- 11.4/16.2 MB 5.8 MB/s eta 0:00:01
#      ----------------------------- ---------- 11.9/16.2 MB 5.8 MB/s eta 0:00:01
#      ------------------------------ --------- 12.5/16.2 MB 5.8 MB/s eta 0:00:01
#      -------------------------------- ------- 13.1/16.2 MB 5.8 MB/s eta 0:00:01
#      --------------------------------- ------ 13.6/16.2 MB 6.5 MB/s eta 0:00:01
#      ----------------------------------- ---- 14.3/16.2 MB 7.0 MB/s eta 0:00:01
#      ------------------------------------ --- 14.8/16.2 MB 7.4 MB/s eta 0:00:01
#      -------------------------------------- - 15.4/16.2 MB 7.5 MB/s eta 0:00:01
#      ---------------------------------------  16.0/16.2 MB 7.8 MB/s eta 0:00:01
#      ---------------------------------------  16.1/16.2 MB 7.8 MB/s eta 0:00:01
#      ---------------------------------------- 16.2/16.2 MB 7.4 MB/s eta 0:00:00
# Requirement already satisfied: packaging in e:\langchain_models\venv\lib\site-packages (from faiss-cpu) (26.2)
# Requirement already satisfied: numpy>=1.25 in e:\langchain_models\venv\lib\site-packages (from faiss-cpu) (2.2.6)
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.14.3
# [notice] A new release of pip is available: 23.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: wikipedia in e:\langchain_models\venv\lib\site-packages (1.4.0)
# Requirement already satisfied: beautifulsoup4 in e:\langchain_models\venv\lib\site-packages (from wikipedia) (4.15.0)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in e:\langchain_models\venv\lib\site-packages (from wikipedia) (2.34.2)
# Requirement already satisfied: certifi>=2023.5.7 in e:\langchain_models\venv\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2026.5.20)
# Requirement already satisfied: idna<4,>=2.5 in e:\langchain_models\venv\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in e:\langchain_models\venv\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2.7.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in e:\langchain_models\venv\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.4.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in e:\langchain_models\venv\lib\site-packages (from beautifulsoup4->wikipedia) (4.15.0)
# Requirement already satisfied: soupsieve>=1.6.1 in e:\langchain_models\venv\lib\site-packages (from beautifulsoup4->wikipedia) (2.9)
# [notice] A new release of pip is available: 23.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_community.retrievers import WikipediaRetriever

# %%
retriever=WikipediaRetriever(top_k_results=2,lang='en')

# %%
query = "Geographical history of India and Pakistan from the perspective of China"

# %%
docs=retriever.invoke(query)

# %%
docs
# Out:
# [Document(metadata={'title': 'Kashmir', 'summary': 'Kashmir ( KASH-meer or  kash-MEER) is the northernmost geographical region of the Indian subcontinent. Until the mid-19th century, the term Kashmir denoted only the Kashmir Valley between the Great Himalayas and the Pir Panjal Range. The term has since also come to encompass a larger area that formerly comprised the princely state of Jammu and Kashmir, and includes the Indian-administered territories of Jammu and Kashmir and Ladakh, the Pakistani-administered territories of Azad Kashmir and Gilgit-Baltistan, and the Chinese-administered territories of Aksai Chin and the Trans-Karakoram Tract.\n\nFollowing centuries of cultural flourishing under Hindu dynasties which ended with the fall of the Lohara dynasty in 1339, Kashmir Valley was ruled by local sultanates until its incorporation into the Mughal Empire in 1586. It later came under the control of the Afghan Durrani Empire in 1752. In 1819, the Sikh Empire, under Ranjit Singh, annexed the Kashmir Valley. In 1846, after the Sikh defeat in the First Anglo-Sikh War, and upon the purchase of the region from the British under the Treaty of Amritsar, the Raja of Jammu, Gulab Singh, became the new ruler of Jammu and Kashmir. The rule of his descendants, under the paramountcy (or tutelage) of the British Crown, lasted until the Partition of India in 1947, when the former princely state of the British Indian Empire became a disputed territory, now administered by three countries: China, India, and Pakistan.', 'source': 'https://en.wikipedia.org/wiki/Kashmir'}, page_content='Kashmir ( KASH-meer or  kash-MEER) is the northernmost geographical region of the Indian subcontinent. Until the mid-19th century, the term Kashmir denoted only the Kashmir Valley between the Great Himalayas and the Pir Panjal Range. The term has since also come to encompass a larger area that formerly comprised the princely state of Jammu and Kashmir, and includes the Indian-administered territories of Jammu and Kashmir and Ladakh, the Pakistani-administered territories of Azad Kashmir and Gilgit-Baltistan, and the Chinese-administered territories of Aksai Chin and the Trans-Karakoram Tract.\n\nFollowing centuries of cultural flourishing under Hindu dynasties which ended with the fall of the Lohara dynasty in 1339, Kashmir Valley was ruled by local sultanates until its incorporation into the Mughal Empire in 1586. It later came under the control of the Afghan Durrani Empire in 1752. In 1819, the Sikh Empire, under Ranjit Singh, annexed the Kashmir Valley. In 1846, after the Sikh defeat in the First Anglo-Sikh War, and upon the purchase of the region from the British under the Treaty of Amritsar, the Raja of Jammu, Gulab Singh, became the new ruler of Jammu and Kashmir. The rule of his descendants, under the paramountcy (or tutelage) of the British Crown, lasted until the Partition of India in 1947, when the former princely state of the British Indian Empire became a disputed territory, now administered by three countries: China, India, and Pakistan.\n\n\n== Etymology ==\nThe word Kashmir is thought to have been derived from Sanskrit and was referred to as káśmīra. A popular local etymology of Kashmir is that it is land desiccated from water.\nAn alternative etymology derives the name from the name of the Vedic sage Kashyapa who is believed to have settled people in this land. Accordingly, Kashmir would be derived from either kashyapa-mir (Kashyapa\'s Lake) or kashyapa-meru (Kashyapa\'s Mountain).\nThe word has been referenced to in a Hindu scripture mantra worshipping the Hindu goddess Sharada and is mentioned to have resided in the land of kashmira, or which might have been a reference to the Sharada Peeth.\nThe Ancient Greeks called the region Kasperia, which has been identified with Kaspapyros of Hecataeus of Miletus (apud Stephanus of Byzantium) and Kaspatyros of Herodotus (3.102, 4.44). Kashmir is also believed to be the country meant by Ptolemy\'s Kaspeiri ...
#  Document(metadata={'title': 'History of India (1947–present)', 'summary': "The history of independent India or history of Republic of India began when the country became an independent sovereign state within the British Commonwealth on 15 August 1947. Direct administration by the British, which began in 1858, affected a political and economic unification of the subcontinent. When British rule came to an end in 1947, the subcontinent was partitioned along religious lines into two separate countries—India, with a majority of Hindus, and Pakistan, with a majority of Muslims, on the midnight of August 14-15 1947.  Concurrently the Muslim-majority northwest and east of British India was separated into the Dominion of Pakistan, by the Partition of India. The partition led to a population transfer of more than 10 million people between India and Pakistan and the death of about one million people. Indian National Congress leader Jawaharlal Nehru became the first Prime Minister of India, but the leader most associated with the independence struggle, Mahatma Gandhi, accepted no office. The constitution adopted in 1950 made India a democratic republic with Westminster style parliamentary system of government, both at federal and state level respectively. The  democracy has been sustained since then. India's sustained democratic freedoms are unique among the world's newly independent states, despite its history being perforated by several crises. and recent worries of democratic backsliding under the premiership of Narendra Modi.\n\nThe country has faced religious violence, casteism, corruption, malnutrition, poverty, unemployment, language conflicts, naxalism, terrorism, separatist insurgencies in Jammu and Kashmir,  North East India and gender-based violence. India has unresolved territorial disputes over Kashmir and Arunachal Pradesh with China which escalated into a war in 1962 and 1967,  Kashmir with Pakistan which resulted in wars in 1947–1948, 1965, 1971 and 1999 and Kalapani with Nepal. India was neutral in the Cold War, and was a leader in the Non-Aligned Movement. However, it made a loose alliance with the Soviet Union from 1971, when Pakistan was allied with the United States and the People's Republic of China.\n\nIndia is a nuclear-weapon state, having conducted its first nuclear test in 1974, followed by another five tests in 1998. From the 1950s to the 1980s, India followed socialist-inspired policies. The economy was influenced by extensive regulation, protectionism and public ownership, leading to pervasive corruption and slow economic growth. Since 1991, India has pursued more economic liberalisation. Today, India is the sixth largest economy in the world by nominal GDP, third largest economy in purchasing parity power and the fastest-growing economy in the world.\nFrom being a relatively struggling country in its formative years, the Republic of India has emerged as a fast growing G20 major economy. India has sometimes been referred to as a great power and a potential superpower given its large and growing economy, military and population.", 'source': 'https://en.wikipedia.org/wiki/History_of_India_(1947%E2%80%93present)'}, page_content="The history of independent India or history of Republic of India began when the country became an independent sovereign state within the British Commonwealth on 15 August 1947. Direct administration by the British, which began in 1858, affected a political and economic unification of the subcontinent. When British rule came to an end in 1947, the subcontinent was partitioned along religious lines into two separate countries—India, with a majority of Hindus, and Pakistan, with a majority of Muslims, on the midnight of August 14-15 1947.  Concurrently the Muslim-majority northwest and east of British India was separated into the Dominion of Pakistan, by the Partition of India. The partition led to a population transfer of more than 10 million people between India and Pakistan and the deat ...

# %%
for i,doc in enumerate(docs):
    print(f"\n-- Result {i+1}---")
    print(f"Content: \n {doc.page_content}")
